# %%
import pandas as pd
import numpy as np
import json
import math
#import cal_paramater from formula_for_battle

# %% [markdown]
# jsonデータの読み込み
# 元データは https://github.com/kotofurumiya/pokemon_data から取得

# %%
f = open("../pokemon_data.json", 'r')
data_j = json.load(f)

data_df = pd.DataFrame(data_j)
data_df.head(10)
# Out:
#     abilities evolutions form hiddenAbilities isMegaEvolution      name  no  \
# 0   [しんりょく, ]        [2]             [ようりょくそ]           False     フシギダネ   1
# 1   [しんりょく, ]        [3]             [ようりょくそ]           False     フシギソウ   2
# 2   [しんりょく, ]         []             [ようりょくそ]           False     フシギバナ   3
# 3  [あついしぼう, ]         []                   []            True   メガフシギバナ   3
# 4     [もうか, ]        [5]              [サンパワー]           False      ヒトカゲ   4
# 5     [もうか, ]        [6]              [サンパワー]           False      リザード   5
# 6     [もうか, ]         []              [サンパワー]           False     リザードン   6
# 7   [かたいツメ, ]         []                   []            True  メガリザードンX   6
# 8     [ひでり, ]         []                   []            True  メガリザードンY   6
# 9   [げきりゅう, ]        [8]             [あめうけざら]           False      ゼニガメ   7
#
#                                                stats        types
# 0  {'hp': 45, 'defence': 49, 'spDefence': 65, 'sp...     [くさ, どく]
# 1  {'hp': 60, 'defence': 63, 'spDefence': 80, 'sp...     [くさ, どく]
# 2  {'hp': 80, 'defence': 83, 'spDefence': 100, 's...     [くさ, どく]
# 3  {'hp': 80, 'defence': 123, 'spDefence': 120, '...     [くさ, どく]
# 4  {'hp': 39, 'defence': 43, 'spDefence': 50, 'sp...      [ほのお, ]
# 5  {'hp': 58, 'defence': 58, 'spDefence': 65, 'sp...      [ほのお, ]
# 6  {'hp': 78, 'defence': 78, 'spDefence': 85, 'sp...   [ほのお, ひこう]
# 7  {'hp': 78, 'defence': 111, 'spDefence': 85, 's...  [ほのお, ドラゴン]
# 8  {'hp': 78, 'defence': 78, 'spDefence': 115, 's...   [ほのお, ひこう]
# 9  {'hp': 44, 'defence': 65, 'spDefence': 64, 'sp...       [みず, ]

# %%
data_df_rm_MegaEvo = data_df.query("isMegaEvolution == False and form == '' ")

# %%
### type情報をparseして２列に持たせ直す
data_df_rm_MegaEvo['type1'] = data_df_rm_MegaEvo['types'].apply(lambda x: x[0])
data_df_rm_MegaEvo['type2'] = data_df_rm_MegaEvo['types'].apply(lambda x: x[1])
# Out:
# /Users/juntamura/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/juntamura/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()

# %%
### 種族値情報をparseして参照しやすい形にする
data_df_rm_MegaEvo['hp'] = data_df_rm_MegaEvo['stats'].apply(lambda x : x['hp'])
data_df_rm_MegaEvo['attack'] = data_df_rm_MegaEvo['stats'].apply(lambda x : x['attack'])
data_df_rm_MegaEvo['defence'] = data_df_rm_MegaEvo['stats'].apply(lambda x : x['defence'])
data_df_rm_MegaEvo['sp_attack'] = data_df_rm_MegaEvo['stats'].apply(lambda x : x['spAttack'])
data_df_rm_MegaEvo['sp_defence'] = data_df_rm_MegaEvo['stats'].apply(lambda x : x['spDefence'])
data_df_rm_MegaEvo['speed'] = data_df_rm_MegaEvo['stats'].apply(lambda x : x['speed'])
# Out:
# /Users/juntamura/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /Users/juntamura/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# /Users/juntamura/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/site-packages/ipykernel/__main__.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/juntamura/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/site-packages/ipykernel/__main__.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/juntamura/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/site-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/juntamura/.pyenv/versions/anaconda3-4.0.0/lib/python3.5/site-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
new_data_df_zukan = data_df_rm_MegaEvo.loc[:,['no','name','type1','type2', 'hp', 'attack', 'defence', 'sp_attack', 'sp_defence', 'speed']]

# %%
new_data_df_zukan.to_csv('pokemon_zukan_rm_MegaEvo.csv', index=False)

# %%
tmp = new_data_df_zukan.head(20)

# %%
tmp
# Out:
#     no   name type1 type2  hp  attack  defence  sp_attack  sp_defence  speed
# 0    1  フシギダネ    くさ    どく  45      49       49         65          65     45
# 1    2  フシギソウ    くさ    どく  60      62       63         80          80     60
# 2    3  フシギバナ    くさ    どく  80      82       83        100         100     80
# 4    4   ヒトカゲ   ほのお        39      52       43         60          50     65
# 5    5   リザード   ほのお        58      64       58         80          65     80
# 6    6  リザードン   ほのお   ひこう  78      84       78        109          85    100
# 9    7   ゼニガメ    みず        44      48       65         50          64     43
# 10   8   カメール    みず        59      63       80         65          80     58
# 11   9  カメックス    みず        79      83      100         85         105     78
# 13  10  キャタピー    むし        45      30       35         20          20     45
# 14  11  トランセル    むし        50      20       55         25          25     30
# 15  12  バタフリー    むし   ひこう  60      45       50         90          80     70
# 16  13   ビードル    むし    どく  40      35       30         20          20     50
# 17  14   コクーン    むし    どく  45      25       50         25          25     35
# 18  15   スピアー    むし    どく  65      90       40         45          80     75
# 20  16    ポッポ  ノーマル   ひこう  40      45       40         35          35     56
# 21  17   ピジョン  ノーマル   ひこう  63      60       55         50          50     71
# 22  18  ピジョット  ノーマル   ひこう  83      80       75         70          70    101
# 24  19   コラッタ  ノーマル        30      56       35         25          35     72
# 26  20    ラッタ  ノーマル        55      81       60         50          70     97

# %%
### 使用予定の6匹を抽出
### 元データの仕様でロトムだけnameではなくformでフィルタなので注意
my_1 = 'ガオガエン'
my_2 = 'ウォッシュロトム'
my_3 = 'メガラティアス'
en_1 = 'テッカグヤ'
en_2 = 'アシレーヌ'
en_3 = 'メガフシギバナ'

pt_data =  data_df.query("name == @my_1 or form == @my_2 or name == @my_3 \
or name == @en_1 or name == @en_2 or name == @en_3")
pt_data
# Out:
#         abilities evolutions      form hiddenAbilities isMegaEvolution  \
# 3      [あついしぼう, ]         []                        []            True
# 436       [ふゆう, ]         []                        []            True
# 551       [ふゆう, ]         []  ウォッシュロトム              []           False
# 826       [もうか, ]         []                     [いかく]           False
# 829     [げきりゅう, ]         []                 [うるおいボイス]           False
# 903  [ビーストブースト, ]         []                        []           False
#
#         name   no                                              stats  \
# 3    メガフシギバナ    3  {'spAttack': 122, 'defence': 123, 'spDefence':...
# 436  メガラティアス  380  {'spAttack': 140, 'defence': 120, 'spDefence':...
# 551      ロトム  479  {'spAttack': 105, 'defence': 107, 'spDefence':...
# 826    ガオガエン  727  {'spAttack': 80, 'defence': 90, 'spDefence': 9...
# 829    アシレーヌ  730  {'spAttack': 126, 'defence': 74, 'spDefence': ...
# 903    テッカグヤ  797  {'spAttack': 107, 'defence': 103, 'spDefence':...
#
#             types
# 3        [くさ, どく]
# 436  [ドラゴン, エスパー]
# 551     [でんき, みず]
# 826     [ほのお, あく]
# 829   [みず, フェアリー]
# 903    [はがね, ひこう]

# %%
hoge = pt_data.query("name == 'メガラティアス'")

# %% [markdown]
# この辺模索中

# %%
param_syuzokuchi = dict(hoge.stats)

# %%
hoge.index[0]
# Out:
# 436

# %%
param_syuzokuchi[hoge.index[0]]['hp']
# Out:
# 80

# %%
param_syuzokuchi[hoge.index[0]]
# Out:
# {'attack': 100,
#  'defence': 120,
#  'hp': 80,
#  'spAttack': 140,
#  'spDefence': 150,
#  'speed': 110}

# %%
### パラメータ計算の関数をこっちに持ってきてみる
def cal_paramater(h,a,b,c,d,s,h_d,a_d,b_d,c_d,d_d,s_d,personal):
    ### 本来的には性格に対するパラメータ補正値を辞書とかで持たせておけば良い気もするが、今回4種しか使わないのでゴリ押し
    if personal == 0:
        a_hosei = 1.1
        b_hosei = 1
        c_hosei = 0.9
        d_hosei = 1
        s_hosei = 1
    elif personal == 1:
        a_hosei = 0.9
        b_hosei = 1
        c_hosei = 1.1
        d_hosei = 1
        s_hosei = 1
    elif personal == 2:
        a_hosei = 1.1
        b_hosei = 1
        c_hosei = 1
        d_hosei = 1
        s_hosei = 0.9
    elif personal == 3:
        a_hosei = 1
        b_hosei = 1
        c_hosei = 1.1
        d_hosei = 1
        s_hosei = 0.9
    else:
        a_hosei = 1
        b_hosei = 1
        c_hosei = 1
        d_hosei = 1
        s_hosei = 1
    
    h_j = math.floor((h + 31/2 + h_d/8)+60)
    a_j = math.floor(((a + 31/2 + a_d/8)+5)*a_hosei)
    b_j = math.floor(((b + 31/2 + b_d/8)+5)*b_hosei)
    c_j = math.floor(((c + 31/2 + c_d/8)+5)*c_hosei)
    d_j = math.floor(((d + 31/2 + d_d/8)+5)*d_hosei)
    s_j = math.floor(((s + 31/2 + s_d/8)+5)*s_hosei)
    
    return h_j, a_j, b_j, c_j, d_j, s_j

# %%
h = param_syuzokuchi[hoge.index[0]]['hp']
a = param_syuzokuchi[hoge.index[0]]['attack']
b = param_syuzokuchi[hoge.index[0]]['defence']
c = param_syuzokuchi[hoge.index[0]]['spAttack']
d = param_syuzokuchi[hoge.index[0]]['spDefence']
s = param_syuzokuchi[hoge.index[0]]['speed']

cal_paramater(h,a,b,c,d,s,252,0,0,252,4,0,1)
### 控えめメガラティアス
# Out:
# (187, 108, 140, 211, 171, 130)
