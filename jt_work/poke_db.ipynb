# %%
from enum import Enum

# %%
class PokeType(Enum):
    """
    ポケモンのタイプ定数
    """
    EMPTY = 1
    NORMAL = 2
    FIRE = 3
    WATER = 4
    ELECTR = 5
    GRASS = 6
    ICE = 7
    FIGHT = 8
    POISON = 9
    GROUND = 10
    FLYING = 11
    PSYCHC = 12
    BUG = 13
    ROCK = 14
    GHOST = 15
    DRAGON = 16
    DARK = 17
    STEEL = 18
    FAIRY = 19

# %% [markdown]
# ### タイプ相性表

# %%
_type_match_dict = {}
_type_match_dict[PokeType.EMPTY] = {
}
_type_match_dict[PokeType.NORMAL] = {
    PokeType.ROCK: 0.5,
    PokeType.GHOST: 0,
    PokeType.STEEL : 0.5,
}
_type_match_dict[PokeType.FIRE] = {
    PokeType.FIRE: 0.5,
    PokeType.WATER: 0.5,
    PokeType.GRASS: 2,
    PokeType.ICE: 2,
    PokeType.BUG: 2,
    PokeType.ROCK: 0.5,
    PokeType.DRAGON: 0.5,
    PokeType.STEEL: 2,
}
_type_match_dict[PokeType.WATER] = {
    PokeType.FIRE: 2,
    PokeType.WATER: 0.5,
    PokeType.GRASS: 0.5,
    PokeType.GROUND: 2,
    PokeType.ROCK: 2,
    PokeType.DRAGON: 0.5,
}
_type_match_dict[PokeType.ELECTR] = {
    PokeType.WATER: 2,
    PokeType.ELECTR: 0.5,
    PokeType.GRASS: 0.5,
    PokeType.GROUND: 0,
    PokeType.FLYING: 2,
    PokeType.DRAGON: 0.5,
}
_type_match_dict[PokeType.GRASS] = {
    PokeType.FIRE: 0.5,
    PokeType.WATER: 2,
    PokeType.GRASS: 0.5,
    PokeType.POISON: 0.5,
    PokeType.GROUND: 2,
    PokeType.FLYING: 0.5,
    PokeType.BUG: 0.5,
    PokeType.ROCK: 2,
    PokeType.DRAGON: 0.5,
    PokeType.STEEL: 0.5,
    
}
_type_match_dict[PokeType.ICE] = {
    PokeType.WATER: 0.5,
    PokeType.GRASS: 2,
    PokeType.ICE: 0.5,
    PokeType.GROUND: 2,
    PokeType.FLYING: 2,
    PokeType.DRAGON: 2,
    PokeType.STEEL: 0.5,
}
_type_match_dict[PokeType.FIGHT] = {
    PokeType.NORMAL: 2,
    PokeType.ICE: 2,
    PokeType.POISON: 0.5,
    PokeType.FLYING: 0.5,
    PokeType.PSYCHC: 0.5,
    PokeType.BUG: 0.5,
    PokeType.ROCK: 2,
    PokeType.GHOST: 0,
    PokeType.DARK: 2,
    PokeType.STEEL: 2,
    PokeType.FAIRY: 0.5,
}
_type_match_dict[PokeType.POISON] = {
    PokeType.GRASS: 2,
    PokeType.POISON: 0.5,
    PokeType.GROUND: 0.5,
    PokeType.BUG: 2,
    PokeType.ROCK: 0.5,
    PokeType.GHOST: 0.5,
    PokeType.STEEL: 0,
    PokeType.FAIRY: 2,
}
_type_match_dict[PokeType.GROUND] = {
    PokeType.FIRE: 2,
    PokeType.ELECTR: 2,
    PokeType.GRASS: 0.5,
    PokeType.POISON: 2,
    PokeType.FLYING: 0,
    PokeType.BUG: 0.5,
    PokeType.ROCK: 2,
    PokeType.STEEL: 2,
}
_type_match_dict[PokeType.FLYING] = {
    PokeType.ELECTR: 0.5,
    PokeType.GRASS: 2,
    PokeType.FIGHT: 2,
    PokeType.BUG: 2,
    PokeType.ROCK: 0.5,
    PokeType.STEEL: 0.5
}
_type_match_dict[PokeType.PSYCHC] = {
    PokeType.FIGHT: 2,
    PokeType.POISON: 2,
    PokeType.PSYCHC: 0.5,
    PokeType.DARK: 0,
    PokeType.STEEL: 0.5,
}
_type_match_dict[PokeType.BUG] = {
    PokeType.FIRE: 0.5,
    PokeType.GRASS: 2,
    PokeType.FIGHT: 0.5,
    PokeType.POISON: 2,
    PokeType.FLYING: 0.5,
    PokeType.PSYCHC: 2,
    PokeType.GHOST: 0.5,
    PokeType.DARK: 2,
    PokeType.STEEL: 0.5,
    PokeType.FAIRY: 0.5
}
_type_match_dict[PokeType.ROCK] = {
    PokeType.FIRE: 2,
    PokeType.ICE: 2,
    PokeType.FIGHT: 0.5,
    PokeType.GROUND: 0.5,
    PokeType.FLYING: 2,
    PokeType.BUG: 2,
    PokeType.STEEL: 0.5,
}
_type_match_dict[PokeType.GHOST] = {
    PokeType.NORMAL: 0,
    PokeType.PSYCHC: 2,
    PokeType.GHOST: 2,
    PokeType.DARK: 0.5,
}
_type_match_dict[PokeType.DRAGON] = {
    PokeType.DRAGON: 2,
    PokeType.STEEL: 0.5,
}
_type_match_dict[PokeType.DARK] = {
    PokeType.FIGHT: 0.5,
    PokeType.PSYCHC : 2,
    PokeType.GHOST: 2,
    PokeType.DARK: 0.5,
    PokeType.FAIRY: 0.5,
    
}
_type_match_dict[PokeType.STEEL] = {
    PokeType.FIRE: 0.5,
    PokeType.WATER: 0.5,
    PokeType.ELECTR: 0.5,
    PokeType.ICE: 2,
    PokeType.ROCK: 2,
    PokeType.STEEL: 0.5,
    PokeType.FAIRY: 2,
}
_type_match_dict[PokeType.FAIRY] = {
    PokeType.FIRE: 0.5,
    PokeType.FIGHT: 2,
    PokeType.POISON: 0.5,
    PokeType.DRAGON: 2,
    PokeType.DARK: 2,
    PokeType.STEEL: 0.5,
}

# %%
_type_match_dict[PokeType.GHOST]
# Out:
# {<PokeType.GHOST: 15>: 2,
#  <PokeType.DARK: 17>: 0.5,
#  <PokeType.NORMAL: 2>: 0,
#  <PokeType.PSYCHC: 12>: 2}

# %% [markdown]
# ### 自前の技マスタ
# name: 技名
# power: 威力
# acc: 命中率
# type: タイプ
# A_spA: 物理 or 特殊

# %%
from collections import defaultdict 
weapon_master = defaultdict(dict)

# %%
weapon_master['1']['name'] = 'ほのおのパンチ'
weapon_master['1']['power'] = 75
weapon_master['1']['acc'] = 100
weapon_master['1']['type'] = PokeType.FIRE
weapon_master['1']['A_spA'] = 'A'
weapon_master['2']['name'] = 'DDラリアット'
weapon_master['2']['power'] = 85
weapon_master['2']['acc'] = 100
weapon_master['2']['type'] = PokeType.DARK
weapon_master['2']['A_spA'] = 'A'
weapon_master['3']['name'] = 'じしん'
weapon_master['3']['power'] = 100
weapon_master['3']['acc'] = 100
weapon_master['3']['type'] = PokeType.GROUND
weapon_master['3']['A_spA'] = 'A'
weapon_master['4']['name'] = 'とんぼがえり'
weapon_master['4']['power'] = 120
weapon_master['4']['acc'] = 100
weapon_master['4']['type'] = PokeType.BUG
weapon_master['4']['A_spA'] = 'A'
weapon_master['5']['name'] = 'ハイドロポンプ'
weapon_master['5']['power'] = 110
weapon_master['5']['acc'] = 80
weapon_master['5']['type'] = PokeType.WATER
weapon_master['5']['A_spA'] = 'spA'
weapon_master['6']['name'] = 'かみなり'
weapon_master['6']['power'] = 110
weapon_master['6']['acc'] = 70
weapon_master['6']['type'] = PokeType.ELECTR
weapon_master['6']['A_spA'] = 'spA'
weapon_master['7']['name'] = 'めざめるパワーこおり'
weapon_master['7']['power'] = 60
weapon_master['7']['acc'] = 100
weapon_master['7']['type'] = PokeType.ICE
weapon_master['7']['A_spA'] = 'spA'
weapon_master['8']['name'] = 'ボルトチェンジ'
weapon_master['8']['power'] = 70
weapon_master['8']['acc'] = 100
weapon_master['8']['type'] = PokeType.ELECTR
weapon_master['8']['A_spA'] = 'spA'
weapon_master['9']['name'] = 'りゅうのはどう'
weapon_master['9']['power'] = 85
weapon_master['9']['acc'] = 100
weapon_master['9']['type'] = PokeType.DRAGON
weapon_master['9']['A_spA'] = 'spA'
weapon_master['10']['name'] = 'サイコキネシス'
weapon_master['10']['power'] = 90
weapon_master['10']['acc'] = 100
weapon_master['10']['type'] = PokeType.PSYCHC
weapon_master['10']['A_spA'] = 'spA'
weapon_master['11']['name'] = 'めざめるパワーほのお'
weapon_master['11']['power'] = 60
weapon_master['11']['acc'] = 100
weapon_master['11']['type'] = PokeType.FIRE
weapon_master['11']['A_spA'] = 'spA'
weapon_master['12']['name'] = 'シャドーボール'
weapon_master['12']['power'] = 80
weapon_master['12']['acc'] = 100
weapon_master['12']['type'] = PokeType.GHOST
weapon_master['12']['A_spA'] = 'spA'
weapon_master['13']['name'] = 'ヘビーボンバー'
weapon_master['13']['power'] = 120
weapon_master['13']['acc'] = 100
weapon_master['13']['type'] = PokeType.STEEL
weapon_master['13']['A_spA'] = 'A'
weapon_master['14']['name'] = 'ストーンエッジ'
weapon_master['14']['power'] = 120
weapon_master['14']['acc'] = 80
weapon_master['14']['type'] = PokeType.ROCK
weapon_master['14']['A_spA'] = 'A'
weapon_master['15']['name'] = 'エナジーボール'
weapon_master['15']['power'] = 80
weapon_master['15']['acc'] = 100
weapon_master['15']['type'] = PokeType.GRASS
weapon_master['15']['A_spA'] = 'spA'
weapon_master['16']['name'] = 'ムーンフォース'
weapon_master['16']['power'] = 90
weapon_master['16']['acc'] = 100
weapon_master['16']['type'] = PokeType.FAIRY
weapon_master['16']['A_spA'] = 'spA'
weapon_master['17']['name'] = 'ヘドロばくだん'
weapon_master['17']['power'] = 90
weapon_master['17']['acc'] = 100
weapon_master['17']['type'] = PokeType.POISON
weapon_master['17']['A_spA'] = 'spA'

# %%
weapon_master
# Out:
# defaultdict(dict,
#             {'1': {'A_spA': 'A',
#               'acc': 100,
#               'name': 'ほのおのパンチ',
#               'power': 75,
#               'type': <PokeType.FIRE: 3>},
#              '10': {'A_spA': 'spA',
#               'acc': 100,
#               'name': 'サイコキネシス',
#               'power': 90,
#               'type': <PokeType.PSYCHC: 12>},
#              '11': {'A_spA': 'spA',
#               'acc': 100,
#               'name': 'めざめるパワーほのお',
#               'power': 60,
#               'type': <PokeType.FIRE: 3>},
#              '12': {'A_spA': 'spA',
#               'acc': 100,
#               'name': 'シャドーボール',
#               'power': 80,
#               'type': <PokeType.GHOST: 15>},
#              '13': {'A_spA': 'A',
#               'acc': 100,
#               'name': 'ヘビーボンバー',
#               'power': 120,
#               'type': <PokeType.STEEL: 18>},
#              '14': {'A_spA': 'A',
#               'acc': 80,
#               'name': 'ストーンエッジ',
#               'power': 120,
#               'type': <PokeType.ROCK: 14>},
#              '15': {'A_spA': 'spA',
#               'acc': 100,
#               'name': 'エナジーボール',
#               'power': 80,
#               'type': <PokeType.GRASS: 6>},
#              '16': {'A_spA': 'spA',
#               'acc': 100,
#               'name': 'ムーンフォース',
#               'power': 90,
#               'type': <PokeType.FAIRY: 19>},
#              '17': {'A_spA': 'spA',
#               'acc': 100,
#               'name': 'ヘドロばくだん',
#               'power': 90,
#               'type': <PokeType.POISON: 9>},
#              '2': {'A_spA': 'A',
#               'acc': 100,
#               'name': 'DDラリアット',
#               'power': 85,
#               'type': <PokeType.DARK: 17>},
#              '3': {'A_spA': 'A',
#               'acc': 100,
#               'name': 'じしん',
#               'power': 100,
#               'type': <PokeType.GROUND: 10>},
#              '4': {'A_spA': 'A',
#               'acc': 100,
#               'name': 'とんぼがえり',
#               'power': 120,
#               'type': <PokeType.BUG: 13>},
#              '5': {'A_spA': 'spA',
#               'acc': 80,
#               'name': 'ハイドロポンプ',
#               'power': 110,
#               'type': <PokeType.WATER: 4>},
#              '6': {'A_spA': 'spA',
#               'acc': 70,
#               'name': 'かみなり',
#               'power': 110,
#               'type': <PokeType.ELECTR: 5>},
#              '7': {'A_spA': 'spA',
#               'acc': 100,
#               'name': 'めざめるパワーこおり',
#               'power': 60,
#               'type': <PokeType.ICE: 7>},
#              '8': {'A_spA': 'spA',
#               'acc': 100,
#               'name': 'ボルトチェンジ',
#               'power': 70,
#               'type': <PokeType.ELECTR: 5>},
#              '9': {'A_spA': 'spA',
#               'acc': 100,
#               'name': 'りゅうのはどう',
#               'power': 85,
#               'type': <PokeType.DRAGON: 16>}})
